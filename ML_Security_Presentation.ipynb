# %% [markdown]
# <a href="https://colab.research.google.com/github/RutgersGRID/mlnotebooks/blob/master/ML_Security_Presentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # The New Canny Valley for Security
#
# What is the Uncanny Valley?
#
# "None of these faces are real"
# * https://www.youtube.com/watch?v=-cOYwZ2XcAc
#
# ## Tools for the Day:
# * Jupyter Notebook/Google Collaboratory
# * Python
# * Tensorflow/Pytorch
#
# ## Hello Machine Learning
#  * tools
#  * techniques
#
# ## Attacking Machine Learning Techniques
# * https://www.youtube.com/watch?v=XSWqLb0VyzM
# * Exploring Neural Networks with Activation Atlases
#  * https://distill.pub/2019/activation-atlas/
#
# ## The One Pixel Hack
# * https://arxiv.org/abs/1710.08864
#
# ## Hacking the Human Vision System
# * Generative Adversairal Networks
#
# ## Hacking the Games People Play: Sports
# * Machine Learning to Determine Baseball Signs to Steal Bases
#  * https://www.youtube.com/watch?v=PmlRbfSavbI
#
# ## eSports
#
# ## Deepmind
#  * Go
#  * Chess
#  * Dota
#  * Star Craft (https://www.youtube.com/watch?v=DMXvkbAtHNY&t=177s)
#
# ## Open AI
# *  Dota (https://www.youtube.com/watch?v=tfb6aEUMC04)
#
# ## The AI Gym
# * https://gym.openai.com/
#
# ## Reinforcement Learning
# * Learnig to Walk
# * Learning to do impossible tasks
#  * https://www.youtube.com/watch?v=GdTBqBnqhaQ
#
# ## Health and Hacking:
# * Identifying Lung Cancer
# * Hack remove Lung Cancer
# * Add Lung Cancer
#
# Minimum pixels a photo needs for a diagnosis
#
# ## Endless Spam
# * Open AI
# * https://openai.com/blog/better-language-models/
# * https://www.youtube.com/watch?v=8ypnLjwpzK8
# * The Unreasonableness of Recurrent Neiral Networks (http://karpathy.github.io/2015/05/21/rnn-effectiveness/)
#
#
# ## DeepFakes
# * https://www.youtube.com/watch?v=aJq6ygTWdao
#
# ## Audio Fakes
# * Looking to Listen
# * https://looking-to-listen.github.io/
#
# ## Unmasking Privacy (Doxing)
# * Crossing Facebook Photos with Youtube or other sites
#
# ## Listening in on Video/Audio
# * https://www.youtube.com/watch?v=zL6ltnSKf9k
# *
#
# ## Tracking People in Video
# * asdf
#
# ## Seeing Through Walls
# * https://www.youtube.com/watch?v=kBFMsY5ZP0o
#
# ## Appendinx of Topics
# https://medium.com/@jason_trost/collection-of-deep-learning-cyber-security-research-papers-e1f856f71042
#
# * Network Intrusion Detection
# * Captcha Recognition (Proving you are human/inhuman)
# *  Botnet Detection
# *  User Verification (keystrokes)
# *  Steganalysis
# *  Name/Domain  Generation
# * Underground Economoy
# * Exposing Trust Networks (Deep Learning for Network Analysis)
# * IOT
#  * Robot Controls
#  * Physicial Device
#  * Car Hacking
#  * Hacking time series data (modifying logs and sequences)
